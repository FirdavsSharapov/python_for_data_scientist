# %% [markdown]
# ### Chapter 4
# #### Segment 1 - Creating standart data graphics

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### Creating a Line chart from a list of object
# #### Ploting a line chart in matplotlib

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x,y)

# %% [markdown]
# #### Plotting  aline chart from a Pandas object

# %%
address = 'C:/Users/Fred/Documents/GitHub/Python_for_data_scientist/data/mtcars.csv'

cars=pd.read_csv(address)

# %%
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

# %%
mpg = cars['mpg']

# %%
mpg.plot()

# %%
df = cars[['cyl','wt','mpg']]
plot_result = df.plot()
plot_result.set_xlabel('test')
# Out:
# Text(0.5, 0, 'test')
